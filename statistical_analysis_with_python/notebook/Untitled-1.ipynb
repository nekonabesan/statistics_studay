# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/home/jovyan/data/ch1_sport_test.csv')
df.head()
# Out:
#    生徒番号  学年    握力  上体起こし  点数  順位
# 0     1   1  40.2     34  15   4
# 1     2   1  34.2     14   7  10
# 2     3   1  28.8     27  11   7
# 3     4   2  39.0     27  14   5
# 4     5   2  50.9     32  17   2

# %%
df['握力']
# Out:
# 0    40.2
# 1    34.2
# 2    28.8
# 3    39.0
# 4    50.9
# 5    36.5
# 6    36.6
# 7    49.2
# 8    26.0
# 9    47.4
# Name: 握力, dtype: float64

# %%
df.shape
# Out:
# (10, 6)

# %%
# %precision 3
pd.set_option('display.precision', 3)
df = pd.read_csv('/home/jovyan/data/ch2_scores_em.csv')
df.head()
# Out:
#    生徒番号  英語  数学
# 0     1  42  65
# 1     2  69  80
# 2     3  56  63
# 3     4  41  63
# 4     5  57  76

# %%
scores = np.array(df['英語'])[:10]
scores
# Out:
# array([42, 69, 56, 41, 57, 48, 65, 49, 65, 58])

# %%
scores_df = pd.DataFrame({'点数': scores}, index=pd.Index(['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J'], name='生徒'))
scores_df
# Out:
#     点数
# 生徒
# A   42
# B   69
# C   56
# D   41
# E   57
# F   48
# G   65
# H   49
# I   65
# J   58

# %%
sum(scores)/len(scores)
# Out:
# 55.000

# %%
np.mean(scores)
# Out:
# 55.000

# %%
scores_df.mean()
# Out:
# 点数    55.0
# dtype: float64

# %%
sorted_scores = sorted(scores)
sorted_scores
# Out:
# [np.int64(41),
#  np.int64(42),
#  np.int64(48),
#  np.int64(49),
#  np.int64(56),
#  np.int64(57),
#  np.int64(58),
#  np.int64(65),
#  np.int64(65),
#  np.int64(69)]

# %%
n = len(sorted_scores)
if n % 2 == 0:
    m0 = sorted_scores[n//2 - 1]
    m1 = sorted_scores[n//2]
    median = (m0 + m1) / 2
else:
    median = sorted_scores[(n+1)//2-1]
median
# Out:
# 56.500

# %%
np.median(scores)
# Out:
# 56.500

# %%
scores_df.median()
# Out:
# 点数    56.5
# dtype: float64

# %%
pd.Series([1, 1, 1, 2, 2, 3]).mode()
# Out:
# 0    1
# dtype: int64

# %%
pd.Series([1, 2, 3, 4, 5]).mode()
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
mean = np.mean(scores)
deviation = scores - mean
deviation
# Out:
# array([-13.,  14.,   1., -14.,   2.,  -7.,  10.,  -6.,  10.,   3.])

# %%
another_scores = [50, 60, 58, 54, 51, 56, 57, 53, 52, 59] 
another_mean = np.mean(another_scores)
another_deviation = another_scores - another_mean
another_deviation
# Out:
# array([-5.,  5.,  3., -1., -4.,  1.,  2., -2., -3.,  4.])

# %%
np.mean(deviation)
# Out:
# 0.000

# %%
np.mean(another_deviation)
# Out:
# 0.000

# %%
summary_df = scores_df.copy()
summary_df['偏差'] = deviation
summary_df
# Out:
#     点数    偏差
# 生徒
# A   42 -13.0
# B   69  14.0
# C   56   1.0
# D   41 -14.0
# E   57   2.0
# F   48  -7.0
# G   65  10.0
# H   49  -6.0
# I   65  10.0
# J   58   3.0

# %%
summary_df.mean()
# Out:
# 点数    55.0
# 偏差     0.0
# dtype: float64

# %%
np.mean(deviation ** 2)
# Out:
# 86.000

# %%
np.var(scores)
# Out:
# 86.000

# %%
scores_df.var()
# Out:
# 点数    95.556
# dtype: float64

# %%
summary_df['偏差二乗'] = np.square(deviation)
summary_df
# Out:
#     点数    偏差   偏差二乗
# 生徒
# A   42 -13.0  169.0
# B   69  14.0  196.0
# C   56   1.0    1.0
# D   41 -14.0  196.0
# E   57   2.0    4.0
# F   48  -7.0   49.0
# G   65  10.0  100.0
# H   49  -6.0   36.0
# I   65  10.0  100.0
# J   58   3.0    9.0

# %%
summary_df.mean()
# Out:
# 点数      55.0
# 偏差       0.0
# 偏差二乗    86.0
# dtype: float64

# %%
np.sqrt(np.var(scores, ddof=0))
# Out:
# 9.274

# %%
np.std(scores, ddof=0)
# Out:
# 9.274

# %%
np.max(scores) - np.min(scores)
# Out:
# np.int64(28)

# %%
scores_Q1 = np.percentile(scores, 25)
scores_Q3 = np.percentile(scores, 75)
scores_IQR = scores_Q3 - scores_Q1
scores_IQR
# Out:
# 15.000

# %%
pd.Series(scores).describe()
# Out:
# count    10.000
# mean     55.000
# std       9.775
# min      41.000
# 25%      48.250
# 50%      56.500
# 75%      63.250
# max      69.000
# dtype: float64

# %%
z = (scores - np.mean(scores)) / np.std(scores, ddof=0)
z
# Out:
# array([-1.402,  1.51 ,  0.108, -1.51 ,  0.216, -0.755,  1.078, -0.647,
#         1.078,  0.323])

# %%
np.mean(z), np.std(z, ddof=0)
# Out:
# (-0.000, 1.000)

# %%
z = 50 + 10 * (scores - np.mean(scores)) / np.std(scores, ddof=0)
z
# Out:
# array([35.982, 65.097, 51.078, 34.903, 52.157, 42.452, 60.783, 43.53 ,
#        60.783, 53.235])

# %%
scores_df['偏差値'] = z
scores_df
# Out:
#     点数     偏差値
# 生徒
# A   42  35.982
# B   69  65.097
# C   56  51.078
# D   41  34.903
# E   57  52.157
# F   48  42.452
# G   65  60.783
# H   49  43.530
# I   65  60.783
# J   58  53.235

# %%
english_scores = np.array(df['英語'])
pd.Series(english_scores).describe()
# Out:
# count    50.00
# mean     58.38
# std       9.80
# min      37.00
# 25%      54.00
# 50%      57.50
# 75%      65.00
# max      79.00
# dtype: float64

# %%
freq, _ = np.histogram(english_scores, bins=10, range=(0, 100))
freq
# Out:
# array([ 0,  0,  0,  2,  8, 16, 18,  6,  0,  0])

# %%
freq_class = [f'{i}~{i + 10}' for i in range(0, 100, 10)]
freq_dist_df = pd.DataFrame({'度数': freq}, index=pd.Index(freq_class, name='階級'))
freq_dist_df
# Out:
#         度数
# 階級
# 0~10     0
# 10~20    0
# 20~30    0
# 30~40    2
# 40~50    8
# 50~60   16
# 60~70   18
# 70~80    6
# 80~90    0
# 90~100   0

# %%
class_value = [(i + (i + 10))// 2 for i in range(0, 100, 10)]
class_value
# Out:
# [5, 15, 25, 35, 45, 55, 65, 75, 85, 95]

# %%
rel_freq = freq / freq.sum()
rel_freq
# Out:
# array([0.  , 0.  , 0.  , 0.04, 0.16, 0.32, 0.36, 0.12, 0.  , 0.  ])

# %%
cum_rel_freq = np.cumsum(rel_freq)
cum_rel_freq
# Out:
# array([0.  , 0.  , 0.  , 0.04, 0.2 , 0.52, 0.88, 1.  , 1.  , 1.  ])

# %%
freq_dist_df['階級値'] = class_value
freq_dist_df['相対度数'] = rel_freq
freq_dist_df['累積相対度数'] = cum_rel_freq
freq_dist_df = freq_dist_df[['階級値', '度数', '相対度数', '累積相対度数']]
freq_dist_df
# Out:
#         階級値  度数  相対度数  累積相対度数
# 階級
# 0~10      5   0  0.00    0.00
# 10~20    15   0  0.00    0.00
# 20~30    25   0  0.00    0.00
# 30~40    35   2  0.04    0.04
# 40~50    45   8  0.16    0.20
# 50~60    55  16  0.32    0.52
# 60~70    65  18  0.36    0.88
# 70~80    75   6  0.12    1.00
# 80~90    85   0  0.00    1.00
# 90~100   95   0  0.00    1.00

# %%
freq_dist_df.loc[freq_dist_df['度数'].idxmax(), '階級値']
# Out:
# np.int64(65)

# %%
import matplotlib.pyplot as plt
plt.rcParams["font.family"] = "IPAexGothic"
plt.rcParams["axes.unicode_minus"] = False
# %matplotlib inline

fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111)

freq, _, _ = ax.hist(english_scores, bins=10, range=(0, 100))
ax.set_xlabel('点数')
ax.set_ylabel('人数')
ax.set_xticks(np.linspace(0, 100, 10+1))
ax.set_yticks(np.arange(0, max(freq)+1))
plt.show()

# %%
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111)

freq, _, _ = ax.hist(english_scores, bins=25, range=(0, 100))
ax.set_xlabel('点数')
ax.set_ylabel('人数')
ax.set_xticks(np.linspace(0, 100, 25+1))
ax.set_yticks(np.arange(0, max(freq)+1))
plt.show()

# %%
fig = plt.figure(figsize=(10, 6))
ax1 = fig.add_subplot(111)
ax2 = ax1.twinx()


weights = np.ones_like(english_scores) / len(english_scores)
freq, _, _ = ax1.hist(english_scores, bins=25, range=(0, 100), weights=weights)
cum_rel_freq = np.cumsum(freq)
class_value = [(i + (i + 4))// 2 for i in range(0, 100, 4)]

ax2.plot(class_value, cum_rel_freq, ls='--', marker='o', color='gray')


ax1.set_xlabel('点数')
ax1.set_ylabel('人数')
ax2.set_ylabel('累積相対度数')
ax1.set_xticks(np.linspace(0, 100, 25+1))

plt.show()

# %%
fig = plt.figure(figsize=(5, 6))
ax = fig.add_subplot(111)
ax.boxplot(english_scores, labels=['英語'])

plt.show()
# Out:
# /tmp/ipykernel_63/1700511579.py:3: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot(english_scores, labels=['英語'])
