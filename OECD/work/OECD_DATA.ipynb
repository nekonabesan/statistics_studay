# %%
import pandas as pd
import datetime as dt
import requests
import pandas_datareader.data as web
from lxml import etree

# %%
DATA_DIR = '/home/jovyan/data/'
# OECD/data/gdp_annual.csv
gdp_annual = pd.read_csv(f'{DATA_DIR}gdp_annual.csv')
# /home/sheepdog/statistics_studay/OECD/data/iip_monthly.csv
iip_monthly = pd.read_csv(f'{DATA_DIR}iip_monthly.csv')
# OECD/data/iip_quarterly.csv
iip_quarterly = pd.read_csv(f'{DATA_DIR}iip_quarterly.csv')
# OECD/data/labor_productivity_annual.csv
labor_productivity_annual = pd.read_csv(f'{DATA_DIR}labor_productivity_annual.csv')
# OECD/data/labor_productivity_ulc_quarterly.csv
labor_productivity_ulc_quarterly = pd.read_csv(f'{DATA_DIR}labor_productivity_ulc_quarterly.csv')

# %%
#gdp_annual.head()

# %%
gdp_annual_can = gdp_annual[gdp_annual['REF_AREA'] == 'CAN'].sort_values('TIME_PERIOD')
gdp_annual_can.head()
# Out:
#    FREQ REF_AREA SECTOR COUNTERPART_SECTOR TRANSACTION INSTR_ASSET ACTIVITY  \
# 0     A      CAN     S1                 S1        B1GQ          _Z       _Z
# 4     A      CAN     S1                 S1        B1GQ          _Z       _Z
# 8     A      CAN     S1                 S1        B1GQ          _Z       _Z
# 12    A      CAN     S1                 S1        B1GQ          _Z       _Z
# 16    A      CAN     S1                 S1        B1GQ          _Z       _Z
#
#    EXPENDITURE UNIT_MEASURE PRICE_BASE TRANSFORMATION TABLE_IDENTIFIER  \
# 0           _Z      USD_PPP         LR              N            T0102
# 4           _Z      USD_PPP         LR              N            T0102
# 8           _Z      USD_PPP         LR              N            T0102
# 12          _Z      USD_PPP         LR              N            T0102
# 16          _Z      USD_PPP         LR              N            T0102
#
#     TIME_PERIOD   OBS_VALUE
# 0          1970  524086.847
# ...
