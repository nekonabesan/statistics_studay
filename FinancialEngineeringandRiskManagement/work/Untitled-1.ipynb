# %% [markdown]
# X,Yが2つの連続確率変数で共同PDF $ f_{XY}(x, y) > 0 $ と共同CDF $F_{XY}(x, y) $ を持っているとする.
# さらに$X$は周辺PDF $ f_{X}(x) > 0 $ と周辺CDF $F_{X}(x) $ を持ち、$Y$は周辺PDF $f_{Y}(y)>0$ と周辺 CDF$F_{Y}(y)$を持ちます。
# $X$が$Y$と独立であることと等価な記述はどれですか?当てはまるものをすべて選んでください。
#
# 1. 共分散については$ Cov(X, Y) = 0 $
# 2. 共同CDFと限界CDFについては $ F_{XY}(x, y) = F_{X}(x) \cdot F_{Y}(y) $
# 3. ジョイントPDFとマージナルPDFについては$ F_{XY}(x, y) = F_{X}(x) \cdot F_{Y}(y) $
# 4. $X$ であり、 $Y, Z$は別の確率変数 を与える条件付き独立です。
# 5. $ P[X<3,Y<1]=P[X<3]P[Y<1] $
# 6. 条件付きPDFについては、$ f_{X|Y}(x|y) = f_{X}(x) $

# %% [markdown]
# $ X $ が二変量正規分布 $ N(\mu, \Sigma) $ に従い $ \mu = [0, 0] $ と $ \Sigma_{1,1} = 1 $、$ \Sigma_{1,2} = 1 $、$ \Sigma_{2,1} = 1 $、$ \Sigma_{2,2} = 2 $ があるとします.
# $ X = (X_{1}, X_{2}) $  PDF の表現として正しいものはどれですか？
#
# 1. $f_{X}(x_{1}, x_{2}) = \displaystyle\frac{1}{\sqrt{2\pi}}e^{ -\frac{1}{2} \left( 2x_{1}^{2} - 2x_{1}x_{2} + x_{2}^{2} \right) }$
# 2. $f_{X}(x_{1}, x_{2}) = \displaystyle\frac{1}{2\pi}e^{ -\frac{1}{2} \left( x_{1}^{2} - 2x_{1}x_{2} + 2x_{2}^{2} \right) }$
# 3. $f_{X}(x_{1}, x_{2}) = \displaystyle\frac{1}{2\pi}e^{ -\frac{1}{2} \left( x_{1}^{2} - 2x_{1}x_{2} + x_{2}^{2} \right) }$
# 4. $f_{X}(x_{1}, x_{2}) = \displaystyle\frac{1}{2\pi}e^{ -\frac{1}{2} \left( 2x_{1}^{2} - 2x_{1}x_{2} + x_{2}^{2} \right) }$

# %% [markdown]
# $ X anad Y $ が共分散0.8を持つ2つの標準正規確率変数、すなわち
# $ X,Y∼N(0,1) $ であるとします.
# $ E[X∣Y =1] $ は何ですか？

# %% [markdown]
# 確率過程
# $ X_n $ がマルチンゲールであるとします。次の記述のうち正しいものはどれですか？当てはまるものをすべて選んでください。
#
# 1. 無条件平均の場合、$ E[ | X_n | ] < \infty $
# 2. 無条件平均の場合、$ E[X_{n}] = E[X_{0}] $
# 3. 条件付き平均については、$ E[X_{n} | F_{m} ] = E[ X_{t}|F_{s} ] $但し任意の$ n,m $に対して $ n > m > 0, t > s > 0 $
# 4. 条件付き平均については、$ E[X_{n + m} | F_{n}] = X_{n} $

# %% [markdown]
# 公平なコインを投げて賭けるとします.
# 各回の利益は$ X_i $とします.
# (i)i-回目のトスで表が出たら、$ X_{i} = 1 $ドル
# (ii)i-回目のトスで裏が出たら、$ X_{i} = -1 $ドル、$ W_{n} = X_{1} + X_{2} + \cdots + X_{n} $ を $ W_{0} = 0 $  とします。
# $ W_{n} $ は $ n $ のトスの後のあなたの総資産を表していることに注意してください.
#
#
# 100 回投げた後のあなたの富が 12ドル であるとして、$ W_{100} = 12 $ 。
# さらに100回投げたら、あなたの期待富はいくらになるでしょうか?
# 但し $ E[W_{200} | W_{100} = 12 ] $です.

# %% [markdown]
# 赤い玉と緑の玉が入っている壷を考えてみましょう。最初は緑と赤のボールが1つずつ入っています。
# (i)ボールが赤の場合、ボールは追加の赤ボールとともに壷に戻されます。
# (ii)ボールが緑の場合、ボールは追加の緑ボールとともに壷に戻されます。
#
#
# $ n $ 回の抽選の後、$ X_{n} が赤玉の数を表すとします。
# 100回の抽選の後、70個の赤玉があったとします。
# $ X_{ 100 } = 70 $ さらに 100 回引いた後の赤玉の期待個数、$E[X_{200} | X_{100} = 70] $は何個ですか。
# 答えを最も近い整数に丸めてください。
#
# ヒント： $ Y_{n} = X_{n} / (n * 2) $を考えてみましょう

# %% [markdown]
# # ブラウン運動とベクトル

# %% [markdown]
# 設問1
#
# $ X_{t} $が標準的なブラウン運動であるとする.
# $ t > s > 0 $に対する  $ E[X_{t} | X_{s} = 1] $ は？

# %% [markdown]
# 設問2
#
# 設問1の続き
# $ s > 0  $の$ E[X_{s + 1}^{2} | X_{s} = 1] $とはなんですか？

# %% [markdown]
# 設問3
#
# 設問1の続き
#
# $ X_{1} = 1 $が与えられたとき、$ X_{2} < 2 $の確率は？
#
# 有効桁数2桁で回答する

# %% [markdown]
# 設問4
#
# $X_{t}$が$ 0 < \mu < +\infty $の幾何学的ブラウン運動であるとします.
# 次の記述の中で正しいものを選択する.
#
# 1. $ X_{t} $はマーチンゲールです
# 2. $ X_{t} $は超マーチンゲール
# 3. $ X_{t}^{2} $はマーチンゲールです
# 4. $ X_{t} $はサブマーチンゲールです

# %% [markdown]
# 設問5
#
# $ X_{t} $が$ \mu = 1 $を持つ幾何学的ブラウン運動であるとする.
#
# $ X_{1} = 1 $が与えられたとき、$ X_{3} < 3 $となる確率を有効桁数2桁で求めよ.

# %% [markdown]
# 設問6
#
#
# $ v_{1} = [1, 1, 1]^{T}, v_{2} = [1, 0, 1]^{T}, v_{3} = [2, 1, 2]^{T} $であるとする.
#
# あてはまるものをすべて選択してください.
#
# 1. $ v_{1},v_{2} $ と $ v_{3} $ は線形独立
# 2. $ v_{1} $ と $ v_{3} $は 線形独立
# 3. $ v_{1} $ は $ v_{2}, v_{3} $ に線形依存
# 4. $ v_{2} $ と $ v_{3} $ は線形独立
# 5. $ v_{1} $ と $ v_{2} $ は線形独立

# %% [markdown]
# 設問7
#
# 線形空間の基底について正しいものをすべて選べ
#
# 1. $ R^{10} $の基底におけるベクトル$ v_{1}, v_{2} $について$ v_{1}^{T} v_{2} = 0 $を満たす必要がある
# 2. $ R^{10} $の基底におけるベクトル$ v_{1}, v_{2} $について$ ||v_{1} || = ||v_{2}|| = 1 $を満たす必要がある
# 3. $ v_{1} = [1, 1, 1]^{T}, v_{2} = [1, 0, 1]^{T} $は$ v_{3} = [2, 1, 2]^{T} R^{3} $の基底になる
# 4. $ R^{5} $は正確に5つのベクトルを持たなければならない
# 5. $ v_{1} = [1, 1, 1]^{T}, v_{2} = [1, 0, 1]^{T} $は$ v_{3} = [1, 1, 0]^{T} R^{3} $の基底になる
# 6. 零ベクトルは規定ベクトルの一つになれない

# %% [markdown]
# 設問8
#
# $ v_{1} $が$ R^{n} $空間におけるすべてのエントリーが1のベクトルで、これを「1-ベクトル」と呼びます.
#
# $ n = 16 $に対する$ ||v_{1}||_{2} $  $ (l_{2}ノルム) $は？

# %% [markdown]
# 設問9
#
# $ v_{1} = [1, 1, 0]^{T}, v_{2} = [1, 0, 1]^{T} $であるとき$ v_{1}, v_{2} $間の角度は？
#
# 但し$ 0 \leq \theta \leq 180 $

# %% [markdown]
# # 最適化問題

# %% [markdown]
# ### 問題1
# アリスが最適化によりヘッジ戦略を構築したい場合、次の記述の中で正しいものはどれですか？
# 正しいものをすべて選んでください。
#
# 1. アリスは各ポジションを変数として使ってください
# 2. アリスはショートポジションを指定する必要はありません。ロングオンリー戦略はショートポジションを許可する戦略と同じ結果を生成するからです
# 3. アリスはショートポジションが制約によって許可されているかどうかを指定する必要があります

# %% [markdown]
# ### 問題2
# 原始線形プログラム$ P = \min_{x} c^{T} subject to Ax \geq b $に対して
# $ c = [1, -1]^{T}, x = [x_{1}, x_{2}],
# A = \begin{bmatrix}
# 1 & -1 \\
# 2 & 1 \\
# \end{bmatrix} b = [1, 1]^{T} $
#
# 双対プログラムを$ u = [u_{1}, u_{2}] $とします。
# 双対プログラムの目的関数はどれですか
#
# 1. $ u_{1} + u_{2} $
# 2. $ u_{1} - u_{2} $
# 3. $ u_{1} + 2 u_{2} $
# 4. $ -u_{1} + u_{2} $

# %% [markdown]
# ### 問題3
# 問題2の続きです
#
# 次の選択肢の中でデュアルプログラムの制約はどれですか？
# あてはまるものをすべて選んでください。
#
# 1. $ u_{1} + 2u_{2} = 1 $
# 2. $ -u_{1} + u_{2} = -1 $
# 3. $ u_{2} \geq 0 $
# 4. $ u_{1} \geq 0 $

# %% [markdown]
# ### 問題4
#
# 問題3の続きです
#
# 制約から、$ u_1 $と$ u_2 $を解くことが出来ますか？
# 強い双対性が成り立つとすると、原子線形プログラム$ P $の最適値は？

# %% [markdown]
# ### 問題5
#
# 最適化問題$ \min_{x \in R} f(x)$について、次の記述の中で正しいものをすべて選んでください。
#
# 1. グローバルミニマムはローカルミニマムでもなければなりません
# 2. ある$ r > 0 $に対して$ f(y) \geq f(x^{*}) $が$ || y - x^{*} \leq r|| $となる場合$ x^{*} $がローカルミニマム
# 3. $ r > 0 $の場合$ f(y) \geq f(x^{*}) $が$ || y - x^{*} || \leq r $と一緒なら$ x^{*} $はローカルミニマムですが、グローバルミニマムではありません
# 4. $ R^{n} $の任意の$ y $に対して$ f(y) \geq f(x^{*}) $がある場合、$ x^{*} $はグローバルミニマム

# %% [markdown]
# ### 問題6
#
# $ f(x_{1}, x_{2}) = x_{1}^{2} + 2x_{1}x_{2} + x_{2}^{3}  $の局所最小値は？有効桁数2桁で回答しなさい

# %% [markdown]
# ### 問題7
#
# 制約$ 2x_{1} + 3x_{2} = 6 $をもつ$ f(x_{2}, x_{2} = \ln x_{1} + \ln x_{2} ) $のグローバル最大値は？有効桁数2桁で回答しなさい
